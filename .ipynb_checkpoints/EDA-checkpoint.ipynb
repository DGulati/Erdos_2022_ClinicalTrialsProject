# %%
# Common packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from seaborn import set_style, pairplot

set_style("whitegrid")

# %% [markdown]
# ## Import Data

# %%
data_Cancer = pd.read_csv('cancer_data_cleaned.csv')

# %%
data_Cardiovascular = pd.read_csv('cardiovascular_data_cleaned.csv')

# %%
data_Respiratory = pd.read_csv('respiratory_data_cleaned.csv')

# %%
data = pd.concat([data_Cancer, data_Cardiovascular, data_Respiratory])
data.keys()
# Out:
# Index(['Rank', 'Title', 'Status', 'Study Results', 'Conditions',
#        'Interventions', 'Outcome Measures', 'Gender', 'Age', 'Phases',
#        'Enrollment', 'Start Date', 'Completion Date', 'Locations', 'URL',
#        'Actual', 'Estimated', 'Countries', 'EFraction', 'Intervention',
#        'Disease', 'Month'],
#       dtype='object')

# %%
#data['Month'].unique()

# %%
# Dictionaries to change strings to associated numbers
# Status
#status_dict = {'Completed': 0, 'Terminated': 1, 'Suspended': 2, 'Withdrawn': 3}
intervention_dict = {'Behavioral': 0, 'Biological': 1, 'Combination Product': 2, 'Device': 3, 'Diagnostic Test': 4, 'Dietary Supplement': 5, 'Drug': 6, 'Genetic': 7, 'Other': 8, 'Procedure': 9, 'Radiation': 10}
phases_dict = {'Early Phase 1': 0, 'Not Applicable': 1, 'Phase 1': 2, 'Phase 1|Phase 2': 3, 'Phase 2': 4, 'Phase 2|Phase 3': 5, 'Phase 3': 6, 'Phase 4': 7}
status_dict = {"Terminated" : 0 , "Completed" : 1}
data['Status'].unique()
# Out:
# array([1, 0])

# %%
# Add numerical value columns for categorical data 
data['Intervention_Num'] = data['Intervention']
data = data.replace({'Intervention_Num': intervention_dict}).copy()

data['Phase_Num'] = data['Phases']
data = data.replace({'Phase_Num': phases_dict}).copy()

# %% [markdown]
# ## Desciptive Statistics

# %% [markdown]
# ##### 4. Look at the data
#
# Here are descriptions of each of the columns for this data set:
# - `Status`:
#     - `Completed`: "The study has ended normally, and participants are no longer being examined or treated"
#     - `Terminated`: "The study has stopped early and will not start again. Participants are no longer being examined or treated."
# - `Study Results`:
# - `Conditions`:
# - `Interventions`:
# - `Outcome Measures`:
# - `Gender`:
# - `Age`:
# - `Phases`:
#     - `Phase 1`: Test on healthy individuals to see if drug side effects (safety)
#     - `Phase 2`: Test on sick individulas to see if effective (efficacy)
#     - `Phase 3`: Test on wide range of individuals (different populations) to see if similar response across population (safety and efficacy data)
#     - `Phase 4`: Post market FDA approval trials more info about safety (safety)
#     - `Not Applicable`: Describes trials without FDA-defined phases, including trials of devices or behavioral interventions.
# - `Enrollment`:
# - `Locations`:
# - `EFraction`:

# %%
data
# Out:
#        Rank                                              Title  Status  \
# 0         1                 Rehabilitation After Breast Cancer       1
# 1         2  Testing Feasibility of Motivational Interviewi...       1
# 2         3  Individualizing Surveillance Mammography for O...       1
# 3         4  Oxcarbazepine Plus Morphine in Patients With R...       0
# 4         5  Immediate-Release Oxycodone Capsules Study in ...       1
# ...     ...                                                ...     ...
# 9995   9996  Convalescent Plasma of Covid-19 to Treat SARS-...       1
# 9996   9997  Effects of Green Tea Extract (GTE) on Systemic...       1
# 9997   9998  Same-session MR-only Simulation and Treatment ...       1
# 9998   9999  Dietary Interventions in Asthma Treatment: Spr...       0
# 9999  10000    Defining and Treating Depression-related Asthma       1
#
#              Study Results                                         Conditions  \
# 0     No Results Available                                      Breast Cancer
# 1     No Results Available                                       Other Cancer
# 2     No Results Available                                      Breast Cancer
# 3     No Results Available                                             Cancer
# 4              Has Results                                             Cancer
# ...                    ...                                                ...
# 9995  No Results Available                                     SARS Pneumonia
# 9996  No Results Available                                             Asthma
# 9997  No Results Available  Malignancy|Metastasis|Hemoptysis|Gastrointesti...
# 9998           Has Results                                     Asthma|Allergy
# 9999  No Results Available                 Asthma|Depression|Childhood Asthma
#
#                                           Interventions  \
# 0     Behavioral: Individually tailored nurse naviga...
# 1                 Behavioral: Motivational Interviewing
# 2                             Other: Communication Tool
# 3                    Drug: Morphine|Drug: Oxcarbazepine
# 4                        Drug: Oxycodone|Drug: Morphine
# ...                                                 ...
# 9995  Biological: Convalescent Plasma of patients wi...
# 9996              Dietary Supplement: green tea extract
# 9997  Device: Volumetric MR imaging|Radiation: Radia...
# 9998     Other: Broccoli Sprouts|Other: Alfalfa Sprouts
# 9999                          Drug: Ipratropium Bromide
#
#                                        Outcome Measures  Gender  \
# 0     Distress|Depression|Anxiety|Health related qua...  Female
# 1     Feasibility of Motivational Interviewing inter...     All
# 2     Rate of change in intentions for mammography i...  Female
# 3     Number of patients with adverse events as a me...     All
# 4     Numerical Rating Scale (NRS)|The Average Dose ...     All
# ...                                                 ...     ...
# 9995  Death|Lenth of stay ICU|Days of Mechanical Ven...     All
# 9996    Serum Inflammatory markers|Respiratory symptoms     All
# 9997  Feasibility of same-session MRI-only simulatio...     All
# 9998  Change in Forced Expiratory Volume at One Seco...     All
# 9999  FEV1 percent change post-ipratropium|FEV1 perc...     All
#
#                                               Age          Phases  ...  \
# 0       18 Years and older   (Adult, Older Adult)  Not Applicable  ...
# 1       18 Years and older   (Adult, Older Adult)  Not Applicable  ...
# 2              75 Years and older   (Older Adult)  Not Applicable  ...
# 3       18 Years and older   (Adult, Older Adult)         Phase 1  ...
# 4     18 Years to 80 Years   (Adult, Older Adult)         Phase 3  ...
# ...                                           ...             ...  ...
# 9995  18 Years to 70 Years   (Adult, Older Adult)         Phase 2  ...
# 9996  18 Years to 70 Years   (Adult, Older Adult)  Not Applicable  ...
# 9997    18 Years and older   (Adult, Older Adult)  Not Applicable  ...
# 9998               18 Years to 49 Years   (Adult)  Not Applicable  ...
# 9999                7 Years to 17 Years   (Child)   Early Phase 1  ...
#
#       Estimated          Countries EFraction        Intervention      Disease  \
# 0         324.0        ['Denmark']  0.953704          Behavioral       Cancer
# 1          54.0  ['United States']  1.000000          Behavioral       Cancer
# 2          45.0  ['United States']  1.000000               Other       Cancer
# 3          12.0  ['United States']  0.083333                Drug       Cancer
# 4         240.0                NaN  1.008333                Drug       Cancer
# ...         ...                ...       ...                 ...          ...
# 9995       80.0         ['Mexico']  0.525000          Biological  Respiratory
# 9996       30.0      ['Hong Kong']  1.000000  Dietary Supplement  Respiratory
# 9997       20.0  ['United States']  1.000000              Device  Respiratory
# 9998       38.0  ['United States']  0.026316               Other  Respiratory
# 9999       40.0  ['United States']  1.000000                Drug  Respiratory
#
#       Month  Intervention_Num Phase_Num  Comp_EF_0.5 Term_EF_0.5
# 0        43                 0       1.0        False       False
# 1         9                 0       1.0        False       False
# 2        26                 8       1.0        False       False
# 3         9                 6       2.0        False        True
# 4        18                 6       6.0        False       False
# ...     ...               ...       ...          ...         ...
# 9995      7                 1       4.0        False       False
# 9996     30                 5       1.0        False       False
# 9997     33                 3       1.0        False       False
# 9998     15                 8       1.0        False        True
# 9999     30                 6       0.0        False       False
#
# [30000 rows x 26 columns]

# %%
# Calculate Percentages of Data based on Disease Type
Status = np.round(data.groupby('Disease')['Status'].value_counts().to_frame()/(data['Status'].count())*100,2)
Intervention = np.round(data.groupby('Disease')['Intervention'].value_counts().to_frame()/(data['Intervention'].count())*100, 2)
Phases = np.round(data.groupby('Disease')['Phases'].value_counts().to_frame()/(data['Phases'].count())*100, 2)
EFraction = np.round(data.groupby('Disease')['EFraction'].value_counts().to_frame()/(data['EFraction'].count())*100, 2)
Gender = np.round(data.groupby('Disease')['Gender'].value_counts().to_frame()/(data['Gender'].count())*100, 2)
Month = np.round(data.groupby('Disease')['Month'].value_counts().to_frame()/(data['Month'].count())*100, 2)

# %%
# Print DataFrames
Status, Intervention, Phases, EFraction, Gender, Month
# Out:
# (                       Status
#  Disease        Status
#  Cancer         1        27.19
#                 0         6.14
#  Cardiovascular 1        29.67
#                 0         3.66
#  Respiratory    1        29.78
#                 0         3.56,
#                                      Intervention
#  Disease        Intervention
#  Cancer         Drug                        20.98
#                 Biological                   3.02
#                 Behavioral                   2.27
#                 Other                        1.99
#                 Procedure                    1.95
#                 Radiation                    1.16
#                 Device                       1.01
#                 Dietary Supplement           0.60
#                 Diagnostic Test              0.18
#                 Genetic                      0.11
#                 Combination Product          0.05
#  Cardiovascular Drug                        14.47
#                 Device                       6.05
#                 Other                        3.94
#                 Behavioral                   3.76
#                 Procedure                    2.77
#                 Dietary Supplement           1.43
#                 Biological                   0.42
#                 Diagnostic Test              0.26
#                 Combination Product          0.08
#                 Genetic                      0.07
#                 Radiation                    0.07
#  Respiratory    Drug                        14.18
#                 Device                       5.43
#                 Biological                   4.22
#                 Other                        3.93
#                 Procedure                    2.15
#                 Behavioral                   2.13
#                 Dietary Supplement           0.67
#                 Diagnostic Test              0.30
#                 Radiation                    0.16
#                 Combination Product          0.11
#                 Genetic                      0.04,
#                                  Phases
#  Disease        Phases
#  Cancer         Phase 2           12.97
#                 Not Applicable     7.00
#                 Phase 1            5.04
#                 Phase 3            4.21
#                 Phase 1|Phase 2    2.61
#                 Phase 4            0.67
#                 Phase 2|Phase 3    0.43
#                 Early Phase 1      0.41
#  Cardiovascular Not Applicable    15.77
#                 Phase 3            5.07
#                 Phase 4            4.90
#                 Phase 2            3.91
#                 Phase 1            2.18
#                 Phase 2|Phase 3    0.65
#                 Phase 1|Phase 2    0.59
#                 Early Phase 1      0.27
#  Respiratory    Not Applicable    13.63
#                 Phase 2            5.48
#                 Phase 3            5.32
#                 Phase 4            3.79
#                 Phase 1            3.22
#                 Phase 1|Phase 2    0.97
#                 Phase 2|Phase 3    0.66
#                 Early Phase 1      0.27,
#                          EFraction
#  Disease     EFraction
#  Cancer      1.000000         8.84
#              0.500000         0.38
#              0.200000         0.19
#              0.600000         0.19
#              0.666667         0.18
#  ...                           ...
#  Respiratory 15.125000        0.00
#              16.173913        0.00
#              19.652000        0.00
#              41.294393        0.00
#              118.370805       0.00
#
#  [7907 rows x 1 columns],
#                         Gender
#  Disease        Gender
#  Cancer         All      19.19
#                 Female    9.34
#                 Male      4.81
#  Cardiovascular All      30.94
#                 Female    1.21
#                 Male      1.17
#  Respiratory    All      32.09
#                 Male      0.73
#                 Female    0.52,
#                     Month
#  Disease     Month
#  Cancer      36      0.55
#              25      0.53
#              33      0.52
#              37      0.50
#              24      0.50
#  ...                  ...
#  Respiratory 24082   0.00
#              24083   0.00
#              24104   0.00
#              24138   0.00
#              24164   0.00
#
#  [1121 rows x 1 columns])

# %%
# Comparison across columns of dataframe
# condition (if)
Disease_Status_EFraction = np.round(data.groupby(['Disease', 'Status'])['EFraction'].value_counts().to_frame(), 2)
Disease_Status_Intervention = np.round(data.groupby(['Disease', 'Status'])['Intervention'].value_counts().to_frame(), 2),
Disease_Status_Phases = np.round(data.groupby(['Disease', 'Status'])['Phases'].value_counts().to_frame(), 2)
Disease_Status_Month = np.round(data.groupby(['Disease', 'Status'])['Month'].value_counts(bins=10).to_frame(), 2)

# %%
# Print DataFrames
Disease_Status_EFraction, Disease_Status_Intervention, Disease_Status_Phases, Disease_Status_Month
# Out:
# (                               EFraction
#  Disease     Status EFraction
#  Cancer      0      1.000000          175
#                     0.200000           39
#                     0.100000           28
#                     0.500000           26
#                     0.166667           24
#  ...                                  ...
#  Respiratory 1      15.125000           1
#                     16.173913           1
#                     19.652000           1
#                     41.294393           1
#                     118.370805          1
#
#  [8568 rows x 1 columns],
#  (                                        Intervention
#   Disease     Status Intervention
#   Cancer      0      Drug                         1301
#                      Biological                    164
#                      Procedure                     102
#                      Other                          77
#                      Radiation                      66
#   ...                                              ...
#   Respiratory 1      Dietary Supplement            187
#                      Diagnostic Test                85
#                      Radiation                      36
#                      Combination Product            27
#                      Genetic                        11
#
#   [66 rows x 1 columns],),
#                                         Phases
#  Disease        Status Phases
#  Cancer         0      Phase 2             828
#                        Phase 1             276
#                        Not Applicable      259
#                        Phase 1|Phase 2     201
#                        Phase 3             191
#                        Phase 4              32
#                        Phase 2|Phase 3      28
#                        Early Phase 1        27
#                 1      Phase 2            3062
#                        Not Applicable     1840
#                        Phase 1            1235
#                        Phase 3            1073
#                        Phase 1|Phase 2     582
#                        Phase 4             169
#                        Phase 2|Phase 3     101
#                        Early Phase 1        96
#  Cardiovascular 0      Not Applicable      440
#                        Phase 4             205
#                        Phase 2             171
#                        Phase 3             160
#                        Phase 1              56
#                        Phase 2|Phase 3      30
#                        Phase 1|Phase 2      24
#                        Early Phase 1        13
#                 1      Not Applicable     4290
#                        Phase 3            1360
#                        Phase 4            1265
#                        Phase 2            1003
#                        Phase 1             597
#                        Phase 2|Phase 3     165
#                        Phase 1|Phase 2     153
#                        Early Phase 1        67
#  Respiratory    0      Not Applicable      370
#                        Phase 2             241
#                        Phase 3             187
#                        Phase 4             132
#                        Phase 1              69
#                        Phase 1|Phase 2      30
#                        Phase 2|Phase 3      30
#                        Early Phase 1         8
#                 1      Not Applicable     3717
#                        Phase 3            1408
#                        Phase 2            1402
#                        Phase 4            1005
#                        Phase 1             898
#                        Phase 1|Phase 2     260
#                        Phase 2|Phase 3     168
#                        Early Phase 1        72,
#                                                         Month
#  Disease        Status
#  Cancer         0      (-51.0, 4778.8]                   1742
#                        (-24248.299, -19370.2]              98
#                        (19268.2, 24098.0]                   2
#                        (-19370.2, -14540.4]                 0
#                        (-14540.4, -9710.6]                  0
#                        (-9710.6, -4880.8]                   0
#                        (-4880.8, -51.0]                     0
#                        (4778.8, 9608.6]                     0
#                        (9608.6, 14438.4]                    0
#                        (14438.4, 19268.2]                   0
#                 1      (-22.0, 4809.2]                   7715
#                        (-24226.313000000002, -19346.8]    423
#                        (19302.8, 24134.0]                  20
#                        (-19346.8, -14515.6]                 0
#                        (-14515.6, -9684.4]                  0
#                        (-9684.4, -4853.2]                   0
#                        (-4853.2, -22.0]                     0
#                        (4809.2, 9640.4]                     0
#                        (9640.4, 14471.6]                    0
#                        (14471.6, 19302.8]                   0
#  Cardiovascular 0      (-2237.6, 203.0]                  1073
#                        (-24227.407, -21762.4]              26
#                        (-21762.4, -19321.8]                 0
#                        (-19321.8, -16881.2]                 0
#                        (-16881.2, -14440.6]                 0
#                        (-14440.6, -12000.0]                 0
#                        (-12000.0, -9559.4]                  0
#                        (-9559.4, -7118.8]                   0
#                        (-7118.8, -4678.2]                   0
#                        (-4678.2, -2237.6]                   0
#                 1      (-53.5, 4779.0]                   8631
#                        (-24264.326, -19383.5]             253
#                        (19276.5, 24109.0]                  17
#                        (-19383.5, -14551.0]                 0
#                        (-14551.0, -9718.5]                  0
#                        (-9718.5, -4886.0]                   0
#                        (-4886.0, -53.5]                     0
#                        (4779.0, 9611.5]                     0
#                        (9611.5, 14444.0]                    0
#                        (14444.0, 19276.5]                   0
#  Respiratory    0      (-55.0, 4776.8]                   1029
#                        (-24262.319, -19382.2]              36
#                        (19272.2, 24104.0]                   2
#                        (-19382.2, -14550.4]                 0
#                        (-14550.4, -9718.6]                  0
#                        (-9718.6, -4886.8]                   0
#                        (-4886.8, -55.0]                     0
#                        (4776.8, 9608.6]                     0
#                        (9608.6, 14440.4]                    0
#                        (14440.4, 19272.2]                   0
#                 1      (-26.5, 4811.6]                   8677
#                        (-24265.382, -19378.9]             239
#                        (19325.9, 24164.0]                  17
#                        (-19378.9, -14540.8]                 0
#                        (-14540.8, -9702.7]                  0
#                        (-9702.7, -4864.6]                   0
#                        (-4864.6, -26.5]                     0
#                        (4811.6, 9649.7]                     0
#                        (9649.7, 14487.8]                    0
#                        (14487.8, 19325.9]                   0)

# %% [markdown]
# ### EFraction Analysis

# %%
#eda_df = pd.DataFrame([data['Status'], data['EFraction']])

# %%
#Statistical 
data['Comp_EF_0.5'] = (data['Status'] == 1) & (data['EFraction'] <= 0.5)
data['Term_EF_0.5'] = (data['Status'] == 0) & (data['EFraction'] <= 0.5)

Terminated_EF_Percent = np.round(data['Term_EF_0.5'].value_counts()[True]/(data['Term_EF_0.5'].value_counts()[True]+data['Comp_EF_0.5'].value_counts()[True])*100)
Terminated_EF_Percent
# Out:
# 52.0

# %%
# EDA with numerical variables
plt.scatter(range(len(data)), data['EFraction'])
#plt.ylim([0,10])
plt.show()

# %%
pairplot(data=data, 
             hue='Status',
             y_vars = ['EFraction'],
             x_vars = ['Phase_Num'])
plt.ylim([0,0.5])
plt.title('EFraction 0 to 0.5 vs. Phase')
plt.show()

# %%
pairplot(data=data, 
             hue='Status',
             y_vars = ['EFraction'],
             x_vars = ['Phase_Num'])
plt.ylim([0.5,1])
plt.title('EFraction 0.5 to 1 vs. Phase')
plt.show()

# %%
pairplot(data=data, 
             hue='Status',
             y_vars = ['EFraction'],
             x_vars = ['Phase_Num'])
plt.ylim([1,2])
plt.title('EFraction 1 to 2 vs. Phase')
plt.show()

# %%
pairplot(data=data, 
             hue='Status',
             y_vars = ['EFraction'],
             x_vars = ['Intervention_Num'])
plt.ylim([0,0.5])
plt.title('EFraction 0 to 0.5 vs. Intervention')
plt.show()

# %%
pairplot(data=data, 
             hue='Status',
             y_vars = ['EFraction'],
             x_vars = ['Intervention_Num'])
plt.ylim([0.5,1])
plt.title('EFraction 0.5 to 1 vs. Intervention')
plt.show()

# %%
pairplot(data=data, 
             hue='Status',
             y_vars = ['EFraction'],
             x_vars = ['Intervention_Num'])
plt.ylim([1,2])
plt.title('EFraction 1 to 2 vs. Intervention')
plt.show()
