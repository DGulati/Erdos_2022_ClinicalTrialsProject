# %%
import pandas as pd
import numpy as np
import seaborn as sns
from dateutil.parser import parse
from datetime import datetime

# %%
cardiovascular_data = pd.read_csv('cardiovascular_data.csv')

# %%
enrollment= pd.read_csv('enrollment_countries_cardiovascular.csv')

# %%
enrollment['NCT Number'] = enrollment['NCT Number'].str[3:].astype('int')

# %%
cardiovascular_data['NCT Number'] = cardiovascular_data['NCT Number'].str[3:].astype('int')

# %%
my_df= cardiovascular_data.set_index('NCT Number').join(enrollment.set_index('NCT Number'))

# %%
my_df['Actual'] = my_df['Actual'].replace('Not Provided',np.NaN)

# %%
my_df['Actual'] = my_df['Actual'].astype('float')

# %%
my_df['Estimated'] = np.where(my_df['Estimated'] == 'Same as current',my_df['Actual'], my_df['Estimated'])

# %%
my_df['Estimated']= my_df['Estimated'].replace('Not Provided',np.NaN)

# %%
my_df['Estimated'] = my_df['Estimated'].astype('float')

# %%
my_df['EFraction']= my_df['Actual']/my_df['Estimated']

# %%
status_dict = {"Terminated" : 0 , "Completed" : 1}

# %%
my_df =my_df.replace({"Status": status_dict})

# %%
my_df["Phases"].unique()
# Out:
# array(['Not Applicable', 'Phase 3', 'Phase 4', 'Phase 2', 'Phase 1',
#        'Early Phase 1', 'Phase 1|Phase 2', 'Phase 2|Phase 3', nan],
#       dtype=object)

# %%
my_df['Countries']= my_df['Countries'].replace('Not Provided',np.NaN)

# %%
my_df["Countries"]= my_df["Countries"].str.split(',')

# %%
my_df["Intervention"]= my_df["Interventions"].str.split(': ').str[0]

# %%
my_df['Intervention'].unique()
# Out:
# array(['Other', 'Behavioral', 'Dietary Supplement', 'Drug', 'Device',
#        'Diagnostic Test', 'Procedure', 'Biological', 'Genetic',
#        'Radiation', 'Combination Product'], dtype=object)

# %%
intervention_dict = {'Drug': 0, 'Behavioral' : 1, 'Radiation': 2, 'Procedure':3,
       'Dietary Supplement':4, 'Biological':5, 'Diagnostic Test':6, 'Device':7,
       'Genetic':8, 'Combination Product':9, 'Other': 10}

# %%
my_df =my_df.replace({"Interventions": intervention_dict})

# %%
my_df['Disease']= 'Cardiovascular'

# %%
my_df['Start Date'] = pd.to_datetime(my_df['Start Date'], errors='coerce').dt.to_period('M')

# %%
my_df['Completion Date'] = pd.to_datetime(my_df['Completion Date'], errors='coerce').dt.to_period('M')

# %%
my_df['Month']= 12 * (my_df['Completion Date'].dt.year - my_df['Start Date'].dt.year) + (my_df['Completion Date'].dt.month - my_df['Start Date'].dt.month)

# %%
my_df
# Out:
#              Rank                                              Title  Status  \
# NCT Number
# 2195934         1  The Orange Juice and Cardiovascular Disease Study       1
# 3532815         2  Lifestyle Intervention for Cardiovascular Dise...       1
# 3771573         3  Rehabilitation With Exercises in Cardiovascula...       1
# 2707432         4  Reducing Cardiovascular Disease Risk Factors i...       1
# 4778891         5  The Impact of Comprehensive Medication Managem...       1
# ...           ...                                                ...     ...
# 2132689      9996  Comparison of Thrombgolytic and Anticoagulatio...       1
# 1416766      9997  CONtrolling Disease Using Inexpensive IT - Hyp...       1
# 2129309      9998  Haemodynamic Effects of Apelin Agonists and An...       1
# 2130765      9999  Substrate Targeted Ablation Using the FlexAbil...       0
# 820352      10000  Safety and Efficacy of Bosentan in Patients Wi...       1
#
#                    Study Results  \
# NCT Number
# 2195934     No Results Available
# 3532815     No Results Available
# 3771573     No Results Available
# 2707432              Has Results
# 4778891     No Results Available
# ...                          ...
# 2132689     No Results Available
# 1416766     No Results Available
# 2129309     No Results Available
# 2130765              Has Results
# 820352      No Results Available
#
#                                                   Conditions  \
# NCT Number
# 2195934                               Cardiovascular Disease
# 3532815                              Cardiovascular Diseases
# 3771573                              Cardiovascular Diseases
# 2707432                              Cardiovascular Diseases
# 4778891                   Cardiovascular Diseases in Old Age
# ...                                                      ...
# 2132689                                   Pulmonary Embolism
# 1416766                       Hypertension|Diabetes Mellitus
# 2129309                          COPD|Pulmonary Hypertension
# 2130765                  Monomorphic Ventricular Tachycardia
# 820352      Heart Failure, Diastolic|Hypertension, Pulmonary
#
#                                                 Interventions  \
# NCT Number
# 2195934     Other: Standard (blonde) orange juice|Other: B...
# 3532815                    Behavioral: Lifestyle Modification
# 3771573            Other: Physical exercise|Other: monitoring
# 2707432                             Behavioral: Heart Matters
# 4778891     Other: Comprehensive Medication Management ser...
# ...                                                       ...
# 2132689     Drug: Actilyse (Thrombolytic therapy)|Drug: He...
# 1416766     Other: Self-monitoring-nurse-primary care prov...
# 2129309     Procedure: Forearm plethysmography|Procedure: ...
# 2130765      Device: Cardiac catheter ablation with ICD/CRT-D
# 820352                           Drug: bosentan|Drug: placebo
#
#                                              Outcome Measures  Gender  \
# NCT Number
# 2195934                        LDL cholesterol|CVD biomarkers     All
# 3532815     Framingham Risk Scores Reduction|Framingham Ri...  Female
# 3771573     Heart rate variability|Respiratoey muscle stre...     All
# 2707432     Change in Weight|Change in Systolic Blood Pres...     All
# 4778891     The impact of CMM services on blood pressure i...     All
# ...                                                       ...     ...
# 2132689     Clinical manifestations of right ventricular f...     All
# 1416766     Change in blood pressure (BP)|Refill adherence...     All
# 2129309     Percentage change in forearm blood flow in the...     All
# 2130765     Number of Subjects Who Experienced an ICD Shoc...     All
# 820352      change in 6 minute waling distance after 12 we...     All
#
#                                                     Age          Phases  ...  \
# NCT Number                                                               ...
# 2195934     25 Years to 84 Years   (Adult, Older Adult)  Not Applicable  ...
# 3532815       30 Years and older   (Adult, Older Adult)  Not Applicable  ...
# 3771573     40 Years to 70 Years   (Adult, Older Adult)  Not Applicable  ...
# 2707432       21 Years and older   (Adult, Older Adult)  Not Applicable  ...
# 4778891            65 Years to 80 Years   (Older Adult)  Not Applicable  ...
# ...                                                 ...             ...  ...
# 2132689       18 Years and older   (Adult, Older Adult)         Phase 4  ...
# 1416766     18 Years to 80 Years   (Adult, Older Adult)  Not Applicable  ...
# 2129309     18 Years to 70 Years   (Adult, Older Adult)  Not Applicable  ...
# 2130765     18 Years to 75 Years   (Adult, Older Adult)  Not Applicable  ...
# 820352      18 Years to 75 Years   (Adult, Older Adult)         Phase 3  ...
#
#             Completion Date  \
# NCT Number
# 2195934             2016-08
# 3532815             2015-09
# 3771573             2020-07
# 2707432             2019-02
# 4778891             2021-01
# ...                     ...
# 2132689             2015-12
# 1416766             2015-07
# 2129309             2014-12
# 2130765             2016-07
# 820352              2014-06
#
#                                                     Locations  \
# NCT Number
# 2195934     Institute of Food Research, Norwich, Norfolk, ...
# 3532815                                                   NaN
# 3771573         Universidade da Amazônia, Belém, Pará, Brazil
# 2707432     Project Momentum Inc., Rocky Mount, North Caro...
# 4778891     Health Care Centre Zagreb - Centre, Zagreb, Cr...
# ...                                                       ...
# 2132689     Silesian Hospital Opava, Opava, Czechia|Univer...
# 1416766     Reliant Medical Group, Worcester, Massachusett...
# 2129309     Vascular Research Unit, Clinical Pharmacology ...
# 2130765     University of Alabama at Birmingham, Birmingha...
# 820352      Hospital Mostviertel Waidhofen/Ybbs, Waidhofen...
#
#                                                     URL Actual Estimated  \
# NCT Number
# 2195934     https://ClinicalTrials.gov/show/NCT02195934   41.0      42.0
# 3532815     https://ClinicalTrials.gov/show/NCT03532815   85.0      85.0
# 3771573     https://ClinicalTrials.gov/show/NCT03771573   20.0      20.0
# 2707432     https://ClinicalTrials.gov/show/NCT02707432  143.0     200.0
# 4778891     https://ClinicalTrials.gov/show/NCT04778891  133.0     133.0
# ...                                                 ...    ...       ...
# 2132689     https://ClinicalTrials.gov/show/NCT02132689  100.0     100.0
# 1416766     https://ClinicalTrials.gov/show/NCT01416766  196.0     400.0
# 2129309     https://ClinicalTrials.gov/show/NCT02129309   20.0      72.0
# 2130765     https://ClinicalTrials.gov/show/NCT02130765   64.0    1453.0
# 820352      https://ClinicalTrials.gov/show/NCT00820352   20.0      60.0
#
#                                                     Countries  EFraction  \
# NCT Number
# 2195934                                      [United Kingdom]   0.976190
# 3532815                                                   NaN   1.000000
# 3771573                                              [Brazil]   1.000000
# 2707432                                       [United States]   0.715000
# 4778891                                             [Croatia]   1.000000
# ...                                                       ...        ...
# 2132689                                             [Czechia]   1.000000
# 1416766                                       [United States]   0.490000
# 2129309                                      [United Kingdom]   0.277778
# 2130765     [Australia,    France,    Italy,    United Kin...   0.044047
# 820352                                              [Austria]   0.333333
#
#            Intervention         Disease Month
# NCT Number
# 2195934           Other  Cardiovascular    25
# 3532815      Behavioral  Cardiovascular     8
# 3771573           Other  Cardiovascular    22
# 2707432      Behavioral  Cardiovascular    23
# 4778891           Other  Cardiovascular    36
# ...                 ...             ...   ...
# 2132689            Drug  Cardiovascular    57
# 1416766           Other  Cardiovascular    47
# 2129309       Procedure  Cardiovascular     6
# 2130765          Device  Cardiovascular    20
# 820352             Drug  Cardiovascular    65
#
# [10000 rows x 22 columns]

# %%
my_df.to_csv('cardiovascular_data_cleaned.csv',index=False)
